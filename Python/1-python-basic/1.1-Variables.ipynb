# %% [markdown]
# # Variables

# %% [markdown]
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a = 100

# %%
## Declaring and Assigning variables

age = 20
height = 5
name = "Sneha"
is_student = True

print("age :", age)
print("height :", height)
print("name : ",name )
# Out:
# age : 20
# height : 5
# name :  Sneha

# %%
## Naming Convention
## Variables names should be descriptive
## They must start with a letter or ans '_' and contain letter, numbers, and underscores
## Variables names are case sensitive

#valid variable names
first_name = "Sneha"
last_name = "Choudhary"

# %%
# invalid variable names
#2age = 30
#first-name = "Sneha"
#@name = "Sneha"

# %%
## Understanding Variable types
## Python is dynamically types, means type of a variable is determined at runtime
age = 20    #int
height = 4.9   #float
is_student = True    #bool

print(type(name))
# Out:
# <class 'str'>

# %%
## Type checking and conversion
type(height)
# Out:
# float

# %%
age = 20
print(type(age))

# Type conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 20
# <class 'str'>

# %%
## dynamic Typing
## Python allows the type of a variable to change as the program executes

var = 10   #int
print(var, type(var))

var = "hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input

age = input("What is your age")
print(age, type(age))
# Out:
# 20 <class 'str'>

# %%
### Simple Calculator
num1 = float(input("Enter first number : "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum: ", sum)
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: ", quotient)
# Out:
# Sum:  35.0
# Difference:  -11.0
# Product:  276.0
# Quotient:  0.5217391304347826
