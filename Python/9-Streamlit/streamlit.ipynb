# %% [markdown]
# # Introduction to Streamlit
#
# Streamlit is an open source app framework for ML and Data Science projects. It allows you to create beautiful web applications for your ML and DS projects with simple python scripts.
